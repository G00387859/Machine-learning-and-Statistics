# %% [markdown]
# ## t-Tests

# %% [markdown]
# #### Packages

# %%
import numpy as np
import pandas as pd
import statsmodels.stats.weightstats as stat
import scipy.stats as ss
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("fivethirtyeight")

# %% [markdown]
# #### Fake data values

# %%
m_a, s_a, m_b, s_b = 1.0, 0.4, 2.0, 0.4
N = 40

a = np.random.normal(loc=m_a, scale=s_a, size=N)
b = np.random.normal(loc=m_b, scale=s_b, size=N)

df = pd.DataFrame({'Category': ['A'] * len(a) + ['B'] * len(b), 'Value': np.hstack([a,b])})

df
# Out:
#    Category     Value
# 0         A  1.374048
# 1         A  1.163048
# 2         A -0.247083
# 3         A  0.749223
# 4         A  1.163744
# ..      ...       ...
# 75        B  2.094616
# 76        B  2.507253
# 77        B  2.072075
# 78        B  1.368125
# 79        B  2.959254
#
# [80 rows x 2 columns]

# %% [markdown]
# #### Plot data

# %%
sns.catplot(x='Category', y='Value', jitter=False, data=df);

# %% [markdown]
# #### T-test

# %%
# The scipy.stats version.
t_ss, p_ss = ss.ttest_ind(a, b)
print(f"P_scipy: {p_ss:0.2f}")
print(f"P_scipy: {t_ss:0.2f}")

print(ss.ttest_ind(a,b))
# Out:
# P_scipy: 0.00
# P_scipy: -10.91
# -------------------------------------------------------
# NameError             Traceback (most recent call last)
# <ipython-input-9-99777333c9d7> in <module>
#       4 print(f"P_scipy: {t_ss:0.2f}")
#       5
# ----> 6 print(stats.ttest_ind(a,b))
#
# NameError: name 'stats' is not defined

# %%
# test statistic, pvalue of the t-test, degrees of freedom used in the t-test
t, p, d = stat.ttest_ind(a, b)
print(f"P: {p:0.2f}")
print(f"P: {t:0.2f}")
print(f"P: {d:0.2f}")
# Out:
# P: 0.00
# P: -10.91
# P: 78.00

# %% [markdown]
# #### Visualisation

# %%
x = np.linspace(-2.0, 4.0, 1000)

y_a = ss.norm.pdf(x, m_a, s_a)
y_b = ss.norm.pdf(x, m_b, s_b)

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x, y_a)
ax.plot(x, y_b)

plt.show()

# %%
x_t = np.linspace(-4.0, 4.0, 1000)
t = ss.t.pdf(x_t, d)
tf = pd.DataFrame({'x': x_t, 't': t})

tcrit = abs(ss.t.ppf(0.025, d))
one = tf[tf['x'] >= tcrit]
two = tf[tf['x'] <= -tcrit]

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x_t, t)
ax.fill_between(one['x'], one['t'], 0, facecolor="red")
ax.fill_between(two['x'], two['t'], 0, facecolor="red")

plt.show()

# %% [markdown]
# #### Type 1 errors - False Postitives

# %%
trials = 10000
N = 100
m_a, m_b, s = 2.0, 2.0, 0.3
rejects = 0

for i in range(trials):
    a = np.random.normal(loc=m_a, scale=s, size=N)
    b = np.random.normal(loc=m_b, scale=s, size=N)
    if ss.ttest_ind(a, b)[1] <= 0.05:
        rejects = rejects + 1

typei = 100.0 * (rejects / trials)
print(f"{typei:0.2f}%")
# Out:
# 5.27%

# %% [markdown]
# #### Type 2 errors - False Negatives

# %%
trials = 10000
N = 100
m_a, m_b, s = 2.0, 2.1, 0.3
dont = 0

for i in range(trials):
    a = np.random.normal(loc=m_a, scale=s, size=N)
    b = np.random.normal(loc=m_b, scale=s, size=N)
    if ss.ttest_ind(a, b)[1] > 0.05:
        dont = dont + 1

typeii = 100.0 * (dont / trials)
print(f"{typeii:0.2f}%")
# Out:
# 35.32%
